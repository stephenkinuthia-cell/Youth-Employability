# %% [markdown]
# ## Slide 1: Title
#
# * Project title: Employability AI System
# * Team members: Not available in project
#
# **Speaker notes:** Introduce the project name and note that the repository does not explicitly list team members.
#
# ---
#
# ## Slide 2: Problem
#
# * Predict graduate employability and support skills-based career readiness
# * Provide personalized skill recommendations and employer matching support
#
# **Speaker notes:** Describe the core problem as a need for data-driven graduate employability prediction and recommendation.
#
# ---
#
# ## Slide 3: Why It Matters
#
# * Helps graduates understand market readiness and improve outcomes
# * Supports employers in matching candidates to roles more effectively
# * Addresses uncertainty around skills, reputation, salary, and remote-work fit
#
# **Speaker notes:** Emphasize the real-world importance of employability assessment and targeted guidance.
#
# ---
#
# ## Slide 4: Objective
#
# * Build a Django app backed by an ML pipeline for employability prediction
# * Generate individualized skill recommendations and career path suggestions
# * Persist trained models and support evaluation and reporting
#
# **Speaker notes:** Summarize the actual implementation goals derived from the repository structure and code.
#
# ---
#
# ## Slide 5: System Overview
#
# * Pipeline: EDA notebooks → feature engineering → model training → evaluation → Django deployment
# * Codebase: `employability-ai-system/src/` contains data, features, models, evaluation, recommendation modules
# * Output: metrics CSVs, trained model artifact, recommendation reports, notebook analysis
#
# **Speaker notes:** Describe the end-to-end workflow as implemented in the repository.
#
# ---
#
# ## Slide 6: Data Overview
#
# * Dataset size: 3,500 samples in `data/processed/final_features.csv`
# * Key features: demand score, employer reputation, remote-work availability, salary, career stage, skill indicators
# * Target variable: `Employment_Rate_12_Months (%)`
#
# **Speaker notes:** Cite the feature engineering documentation and final feature dataset metadata.
#
# ---
#
# ## Slide 7: Key EDA Insights
#
# * The notebooks explore employability relationships with salary, reputation, remote work, and field of study
# * `Employment_Rate_12_Months (%)` is the primary outcome used for prediction
# * The project uses region, degree level, and skill patterns to understand employability risk
#
# **Speaker notes:** Note that the EDA notebooks focus on data quality, feature relationships, and outcome patterns.
#
# ---
#
# ## Slide 8: Feature Engineering
#
# * Derived interaction features: `Demand_x_Reputation`, `Demand_x_Remote`, `Reputation_x_Remote`
# * Added features: `Unique_Skills_Count`, `Years_Since_Graduation`, `Career_Stage`, `Salary_Per_Year_Experience`, `Is_US`
# * Applied one-hot encoding, scaling, and feature selection to produce 103 final features
#
# **Speaker notes:** Explain the modular feature pipeline from build to transform to select.
#
# ---
#
# ## Slide 9: Models & Performance
#
# * Models used: Logistic Regression, Random Forest, Gradient Boosting classifier
# * Baseline metrics: Gradient Boosting accuracy ~0.743, ROC-AUC ~0.792 from `classification_model_results.csv`
# * Reported evaluation documentation shows best model performance around 91.57% accuracy and 97.14% ROC-AUC on a 700-sample test set
# * Best model: Gradient Boosting classifier is selected as the top model in project artifacts
#
# **Speaker notes:** Report actual model names and evaluation metrics from the repository outputs.
#
# ---
#
# ## Slide 10: Model Insights
#
# * Key drivers are implied by feature engineering: demand, reputation, remote work, salary, and skill portfolio
# * No explicit feature importance ranking is available in the codebase
# * Prediction logic centers on derived market-fit interactions and skill readiness
#
# **Speaker notes:** Explain that the repository emphasizes engineered features and prediction outcomes rather than a separate importance report.
#
# ---
#
# ## Slide 11: Recommendation System
#
# * Personalizes recommendations via skill gap analysis and weak feature identification
# * Uses counterfactual simulation: add missing skills or boost feature values, then predict employability probability change
# * Ranks actions by predicted improvement and formats top recommendations with summary metrics
#
# **Speaker notes:** Describe the actual recommendation workflow from `recommend.py`, `simulate.py`, and `rank.py`.
#
# ---
#
# ## Slide 12: Dashboard / Application
#
# * App reference: `employabilityapp` Django project
# * Functionality: prediction dashboard, personalized feedback, skill recommendations, career path suggestions, role-based access, job matching support
#
# **Speaker notes:** Summarize the user-facing app features and the integration of the ML pipeline.
#
# ---
#
# ## Slide 13: Key Insights
#
# * The platform blends ML prediction with heuristic scoring and recommendation generation
# * Recommendations are driven by both missing skills and weak employability features
# * The app delivers strengths/weaknesses summaries and next-step guidance for users
#
# **Speaker notes:** Highlight the main outcomes from the project’s analytical and application layers.
#
# ---
#
# ## Slide 14: Conclusion
#
# * The repository implements an end-to-end employability AI system with training, evaluation, and deployment
# * It supports graduate readiness assessment and actionable upskilling guidance
# * Evaluation artifacts show strong reported performance and a focus on fairness analysis
#
# **Speaker notes:** Wrap up the project’s achievements using the combined codebase and documentation.
#
# ---
#
# ## Slide 15: Future Work
#
# * Improve model explainability and explicit feature importance reporting
# * Extend fairness analysis to more demographic subgroups and intersectional groups
# * Validate recommendations with real-world job matching and user feedback
# * Monitor deployed model performance and update as market conditions change
#
# **Speaker notes:** Suggest next steps grounded in the project’s documented limitations and enhancement notes.
